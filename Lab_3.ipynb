# %% [markdown]
# <a href="https://colab.research.google.com/github/Rani4477/Day-1-challenge/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-16 06:22:17--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   122MB/s    in 0.6s
#
# 2025-03-16 06:22:20 (122 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3227 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 11396  1512.04808v1  Pattern recognition in neuroimaging distinguis...  stat
# 3708   1705.02687v1  With pressure to increase graduation rates and...  stat
# 14238   1302.3407v1  The problem of change-point estimation is cons...  stat
# 4172   1611.08657v5  Constrained Local Models (CLMs) are a well-est...    cs
# 30696  1801.00553v3  Deep learning is at the heart of the current r...    cs
# ...             ...                                                ...   ...
# 1266   1711.05852v1  Deep learning networks have achieved state-of-...    cs
# 35483   0709.2506v1  Data collection often results in records that ...    cs
# 27256  1703.00312v2  This paper proposes a novel approach for uncer...    cs
# 9012   1702.07680v1  Word embedding models offer continuous vector ...    cs
# 21618   1201.6082v1  In many situations where the interest lies in ...  stat
#
#                                                    title  year  \
# 11396  Causal and anti-causal learning in pattern rec...  2015
# 3708   Finding Bottlenecks: Predicting Student Attrit...  2017
# 14238  A consistent clustering-based approach to esti...  2013
# 4172   Convolutional Experts Constrained Local Model ...  2016
# 30696  Threat of Adversarial Attacks on Deep Learning...  2018
# ...                                                  ...   ...
# 1266   Apprentice: Using Knowledge Distillation Techn...  2017
# 35483  Autoencoder, Principal Component Analysis and ...  2007
# 27256  Perturb-and-MPM: Quantifying Segmentation Unce...  2017
# 9012       Consistent Alignment of Word Embedding Models  2017
# 21618   A robust and sparse K-means clustering algorithm  2012
#
#                                                 keywords
# 11396  [recognition, neuroimaging, distinguishes, dis...
# 3708   [graduation, education, important, automated, ...
# 14238  [estimation, considered, framework, generated,...
# 4172   [constrained, established, detection, regressi...
# 30696  [artificial, intelligence, workhorse, applicat...
# ...                                                  ...
# 1266   [accuracies, workloads, classification, detect...
# 35483  [collection, variables, investigation, differe...
# 27256  [uncertainty, quantification, conditional, pre...
# 9012   [embedding, continuous, representations, conte...
# 21618  [situations, identifying, available, variables...
#
# [4581 rows x 6 columns]

# %%
df['keywords']
# Out:
# 11396    [recognition, neuroimaging, distinguishes, dis...
# 3708     [graduation, education, important, automated, ...
# 14238    [estimation, considered, framework, generated,...
# 4172     [constrained, established, detection, regressi...
# 30696    [artificial, intelligence, workhorse, applicat...
#                                ...
# 13492    [transport, important, societies, interested, ...
# 7320     [detecting, distribution, distribution, distri...
# 28428    [capturing, anisotropic, diffusion, diffusion,...
# 39769    [deforestation, detection, satellite, importan...
# 21865    [practical, processes, consuming, different, v...
# Name: keywords, Length: 5727, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8550 words.
# Out of those 4459 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f8585d85-d1cf-41ac-95e8-e4b1db2cf2a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f8585d85-d1cf-41ac-95e8-e4b1db2cf2a8")) {                    Plotly.newPlot(                        "f8585d85-d1cf-41ac-95e8-e4b1db2cf2a8",                        [{"x":["relations","neuroimaging","experimental","justification","interpretation","essential","distinguishes","sufficient","represent","recognition","inference","different","distinction","theoretical","depending","education","bottlenecks","university","bottleneck","unsupervised","techniques","desirable","automated","classifier","therefore","predicting","clustering","important","california","additional","framework","parameter","constraint","evaluations","considered","dependent","asymptotically","algorithm","estimating","empirical","applications","distributions","consistent","generated","estimation","impossible","estimates","stationary","detection","detectors","illumination","competitive","challenging","expression","convolutional","individual","architectures","appearance","outperforms","constrained","advantages","established","available","baselines","demonstrate","inability","especially","approaches","regression","direction","vulnerable","adversarial","phenomenal","practical","literature","demonstrated","perturbations","comprehensive","separately","scenarios","conditions","intelligence","completely","contributions","artificial","incorrect","workhorse","existence","emphasize","surveillance","substantiate","segmenting","efficient","significant","solutions","reformulation","guarantee","implementation","complexity","generates","subspaces","minimization","experiments","estimated","synthetic","dimension","extensive","regularized","converges","observations","footprint","realistic","dictionary","extensions","likelihood","algorithms","correlation","describing","parameters","canonical","dimensionality","dimensional","analytical","variational","probabilistic","structure","evaluated","superiority","converted","assessing","necessary","competing","reduction","interpretability","convergence","preserving","attention","dependency","statistically","inflectional","variation","grammatical","relationships","differences","languages","strategies","sentences","translations","expressed","principle","information","statistical","quantitative","informative","stylistic","restricted","approximately","structural","relational","formulate","extensively","supervised","biological","hypergraphs","introduce","potential","successful","instances","methodologies","classification","hypergraph","prediction","unlabeled","methodology","interaction","generalization","interacts","disparate","enumeration","accurately","adversary","interestingly","hypothesize","annotations","structured","community","predicted","constitutes","parametrization","segmentation","discriminates","utilizing","challenges","inherently","breakthroughs","particular","trainable","relevance","sensitivity","particularly"],"y":[86,2,375,8,53,67,3,56,88,327,177,691,4,149,34,14,3,8,22,128,335,26,91,130,142,70,170,322,2,101,499,116,95,35,117,71,9,773,58,133,391,103,78,188,188,20,59,33,302,31,34,112,248,44,335,116,110,63,231,61,82,44,232,51,510,6,109,382,94,52,12,80,1,128,125,72,18,60,28,97,124,84,37,56,107,6,2,33,6,22,2,24,387,234,132,3,29,138,222,46,17,65,536,52,150,56,144,30,18,74,12,42,52,42,59,562,68,36,223,26,55,172,27,47,155,310,131,48,15,20,77,27,93,19,104,45,145,38,21,3,63,16,65,47,97,83,70,11,37,50,640,141,53,50,3,57,40,64,38,51,36,168,53,3,305,156,64,95,15,471,2,207,27,59,82,91,5,4,5,68,7,12,9,55,83,62,45,15,6,180,4,32,105,23,8,246,20,40,33,75],"type":"bar"},{"x":["relations","neuroimaging","experimental","justification","interpretation","essential" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4459,), (4459, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8342059336823735

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>FPGA</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>Implementation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>CAR</span> <span style=''>Model</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Cochlea</span> <br/><br/><span style=''>The</span> <span style=''>front</span> <span style=''>end</span> <span style=''>of</span> <span style=''>the</span> <span style=''>human</span> <span style=''>auditory</span> <span style=''>system</span> <span style=''>the</span> <span style=''>cochlea</span> <span style=''>converts</span> <span style=''>sound</span> <span style=''>signals</span> <span style=''>from</span> <span style=''>the</span> <span style=''>outside</span> <span style=''>world</span> <span style=''>into</span> <span style=''>neural</span> <span style=''>impulses</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>transmitted</span> <span style=''>along</span> <span style=''>the</span> <span style=''>auditory</span> <span style=''>pathway</span> <span style=''>for</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.44949494949494956);'>processing</span> <span style=''>The</span> <span style=''>cochlea</span> <span style=''>senses</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>separates</span> <span style=''>sound</span> <span style=''>in</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3710691823899371);'>nonlinear</span> <span style=''>active</span> <span style=''>fashion</span> <span style='background-color:rgba(0, 255, 0, 0.39999999999999997);'>exhibiting</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>remarkable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sensitivity</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frequency</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>discrimination</span> <span style=''>Although</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>electronic</span> <span style=''>models</span> <span style=''>of</span> <span style=''>the</span> <span style=''>cochlea</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333334);'>implemented</span> <span style=''>none</span> <span style=''>of</span> <span style=''>these</span> <span style=''>are</span> <span style=''>able</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>reproduce</span> <span style=''>all</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.4014598540145986);'>characteristics</span> <span style=''>of</span> <span style=''>the</span> <span style=''>cochlea</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>including</span> <span style=''>large</span> <span style=''>dynamic</span> <span style=''>range</span> <span style=''>large</span> <span style=''>gain</span> <span style=''>and</span> <span style=''>sharp</span> <span style=''>tuning</span> <span style=''>at</span> <span style=''>low</span> <span style=''>sound</span> <span style=''>levels</span> <span style=''>and</span> <span style=''>low</span> <span style=''>gain</span> <span style=''>and</span> <span style=''>broad</span> <span style=''>tuning</span> <span style=''>at</span> <span style=''>intense</span> <span style=''>sound</span> <span style=''>levels</span> <span style=''>Here</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implement</span> <span style=''>the</span> <span style=''>Cascade</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Asymmetric</span> <span style=''>Resonators</span> <span style=''>(CAR)</span> <span style=''>model</span> <span style=''>of</span> <span style=''>the</s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style=''>Pseudo</span> <span style=''>input</span> <span style=''>Local</span> <span style=''>Kriging</span> <span style=''>for</span> <span style=''>Large</span> <span style=''>Non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stationary</span> <span style=''>Spatial</span> <span style=''>Datasets</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Exogenous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variables</span> <br/><br/><span style=''>Gaussian</span> <span style=''>process</span> <span style=''>(GP)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>is</span> <span style=''>a</span> <span style=''>powerful</span> <span style=''>tool</span> <span style=''>for</span> <span style=''>building</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>predictive</span> <span style=''>models</span> <span style=''>for</span> <span style=''>spatial</span> <span style=''>systems</span> <span style=''>However</span> <span style=''>it</span> <span style=''>does</span> <span style=''>not</span> <span style=''>scale</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>for</span> <span style=''>large</span> <span style=''>datasets</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Particularly</span> <span style=''>for</span> <span style=''>high</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimensional</span> <span style=''>spatial</span> <span style=''>datasets</span> <span style=''>ie</span> <span style=''>spatial</span> <span style=''>datasets</span> <span style=''>that</span> <span style=''>contain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exogenous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>GP</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regression</span> <span style=''>further</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>deteriorates</span> <span style=''>This</span> <span style=''>paper</span> <span style=''>presents</span> <span style=''>the</span> <span style=''>Sparse</span> <span style=''>Pseudo</span> <span style=''>input</span> <span style=''>Local</span> <span style=''>Kriging</span> <span style=''>(SPLK)</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximates</span> <span style=''>the</span> <span style=''>full</span> <span style=''>GP</span> <span style=''>for</span> <span style=''>spatial</span> <span style=''>datasets</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>exogenous</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variables</span> <span style=''>SPLK</span> <span style=''>employs</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style=''>cuts</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>decompose</span> <span style=''>the</span> <span style=''>domain</span> <span style=''>into</span> <span style=''>smaller</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subdomains</span> <span style=''>and</span> <span style=''>then</span> <span style=''>applies</span> <span style=''>a</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>of</span> <span style=''>the</span> <span style=''>full</span> <span style=''>GP</span> <span style=''>in</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>subdomain</span> <span style=''>We</span> <span style=''>obtain</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuity</span> <span style=''>of</span> <span style=''>the</span> <span styl ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Distributed</span> <span style=''>Strongly</span> <span style=''>Convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>A</span> <span style=''>lot</span> <span style=''>of</span> <span style=''>effort</span> <span style=''>has</span> <span style=''>been</span> <span style=''>invested</span> <span style=''>into</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>characterizing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.37724550898203585);'>convergence</span> <span style=''>rates</span> <span style=''>of</span> <span style=''>gradient</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>non</span> <span style=''>linear</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>Recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>motivated</span> <span style=''>by</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>the</span> <span style=''>interest</span> <span style=''>has</span> <span style=''>shifted</span> <span style=''>towards</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>distributed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>strongly</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>Each</span> <span style=''>node</span> <span style=''>in</span> <span style=''>a</span> <span style=''>network</span> <span style=''>of</span> <span style=''>n</span> <span style='background-color:rgba(0, 255, 0, 0.5714285714285715);'>computers</span> <span style='background-color:rgba(255, 0, 0, 0.4705882352941176);'>converges</span> <span style=''>to</span> <span style=''>the</span> <span style=''>optimum</span> <span style=''>of</span> <span style=''>a</span> <span style=''>strongly</span> <span style=''>convex</span> <span style=''>L</span> <span style=''>Lipchitz</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>continuous</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>separable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>at</span> <span style=''>a</span> <span style=''>rate</span> <span style=''>O(log</span> <span style=''>(sqrt(n)</span> <span style=''>T)</span> <span style=''>T)</span> <span style=''>where</span> <span style=''>T</span> <span style=''>is</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>iterations</span> <span style=''>This</span> <span style=''>rate</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>in</span> <span style=''>the</span> <span style=''>online</span> <span style=''>setting</span> <span style=''>where</span> <span style=''>the</span> <span style=''>data</span> <span style=''>is</span> <span style=''>revealed</span> <span style=''>one</span> <span style=''>at</span> <span style=''>a</span> <span style=''>time</span> <span style=''>to</span> <span style=''>the</span> <span style=''>nodes</span> <span style=''>and</span> <span style=''>in</span> <span style=''>the</span> <span style=''>batch</span> <spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Survey</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>improving</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unbalanced</span> <span style=''>datasets</span> <br/><br/><span style=''>A</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>problems</span> <span style=''>need</span> <span style=''>to</span> <span style=''>deal</span> <span style=''>with</span> <span style=''>data</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imbalance</span> <span style=''>between</span> <span style=''>classes</span> <span style=''>Often</span> <span style=''>it</span> <span style=''>is</span> <span style=''>desired</span> <span style=''>to</span> <span style=''>have</span> <span style=''>a</span> <span style=''>high</span> <span style=''>recall</span> <span style=''>on</span> <span style=''>the</span> <span style=''>minority</span> <span style=''>class</span> <span style=''>while</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>maintaining</span> <span style=''>a</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precision</span> <span style=''>on</span> <span style=''>the</span> <span style=''>majority</span> <span style=''>class</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>review</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>resampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>techniques</span> <span style=''>proposed</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>literature</span> <span style=''>to</span> <span style=''>handle</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unbalanced</span> <span style=''>datasets</span> <span style=''>and</span> <span style=''>study</span> <span style=''>their</span> <span style=''>effect</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performance</span> <br/><br/>

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.09041309431021044)
# 	representation (0.13250194855806702)
# 	segmentation (0.0701480904130943)
# 	processing (0.11184723304754482)
# 	detection (0.11769290724863601)
# 	information (0.24941543257989088)
# 	experimental (0.1461418550272798)
# 	different (0.26929072486360095)
# 	recognition (0.127435697583788)
# 	convolutional (0.13055339049103662)
#
# Some Statistics words are:
# 	stochastic (0.14193548387096774)
# 	variables (0.1359801488833747)
# 	estimation (0.1662531017369727)
# 	algorithm (0.3970223325062035)
# 	theoretical (0.15483870967741936)
# 	statistical (0.15285359801488835)
# 	distribution (0.1791563275434243)
# 	inference (0.1880893300248139)
# 	dimensional (0.18759305210918115)
# 	regression (0.18312655086848637)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="241c18da-4016-4cd9-9966-1d47752925e8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("241c18da-4016-4cd9-9966-1d47752925e8")) {                    Plotly.newPlot(                        "241c18da-4016-4cd9-9966-1d47752925e8",                        [{"x":["relations","neuroimaging","experimental","justification","interpretation","essential","distinguishes","sufficient","represent","recognition","inference","different","distinction","theoretical","depending","education","bottlenecks","university","bottleneck","unsupervised","techniques","desirable","automated","classifier","therefore","predicting","clustering","important","california","additional","framework","parameter","constraint","evaluations","considered","dependent","asymptotically","algorithm","estimating","empirical","applications","distributions","consistent","generated","estimation","impossible","estimates","stationary","detection","detectors","illumination","competitive","challenging","expression","convolutional","individual","architectures","appearance","outperforms","constrained","advantages","established","available","baselines","demonstrate","inability","especially","approaches","regression","direction","vulnerable","adversarial","phenomenal","practical","literature","demonstrated","perturbations","comprehensive","separately","scenarios","conditions","intelligence","completely","contributions","artificial","incorrect","workhorse","existence","emphasize","surveillance","substantiate","segmenting","efficient","significant","solutions","reformulation","guarantee","implementation","complexity","generates","subspaces","minimization","experiments","estimated","synthetic","dimension","extensive","regularized","converges","observations","footprint","realistic","dictionary","extensions","likelihood","algorithms","correlation","describing","parameters","canonical","dimensionality","dimensional","analytical","variational","probabilistic","structure","evaluated","superiority","converted","assessing","necessary","competing","reduction","interpretability","convergence","preserving","attention","dependency","statistically","inflectional","variation","grammatical","relationships","differences","languages","strategies","sentences","translations","expressed","principle","information","statistical","quantitative","informative","stylistic","restricted","approximately","structural","relational","formulate","extensively","supervised","biological","hypergraphs","introduce","potential","successful","instances","methodologies","classification","hypergraph","prediction","unlabeled","methodology","interaction","generalization","interacts","disparate","enumeration","accurately","adversary","interestingly","hypothesize","annotations","structured","community","predicted","constitutes","parametrization","segmentation","discriminates","utilizing","challenges","inherently","breakthroughs","particular","trainable","relevance","sensitivity","particularly","pronounced","aggressive","characteristic","complementary","asymmetric","consecutive","incomplete","application","confidence","typically","persistent","influential","defenders","cybersecurity","associative","increasingly","distribution","decisions","compromised","achieving","repeatedly","constraints","subjected","approximation","flexibility","minimizing","sensitive","polynomials","admissible","functions","corresponding","motivated","evaluation","guarantees","specialized","diagnosis","fuzziness","organising","activities","technique","technical","formulation","optimising","presented","membership","objective","furthermore","satisfaction","mathematical","usefulness","preference","incorporating","fundamentals","manufacturing","introduction","p ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	normalised
# 	resistant
# 	generalises
# 	determinantal
# 	dominates
# 	mcallester
# 	ulcerative
# 	substantive
# 	datastreams
# 	selections
# 	parallelized
# 	submanifolds
# 	dendrogram
# 	forecasted
# 	infection
# 	literally
# 	statisticians
# 	profitable
# 	quadrature
# 	imaginary
# Some words which never appear in Statistics papers:
# 	inflectional
# 	grammatical
# 	stylistic
# 	breakthroughs
# 	subjected
# 	fuzziness
# 	organising
# 	accordance
# 	broadcasting
# 	axiomatization
# 	propositional
# 	requested
# 	morphologically
# 	untrimmed
# 	benchmarked
# 	consisted
# 	concurrent
# 	reflection
# 	reverberation
# 	meticulous

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.32016335203692e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.81239092495637
